# %%
from __future__ import division
# %matplotlib inline

import pandas
import matplotlib.pyplot as plt
import numpy
import scipy
import seaborn
seaborn.set_context({"figure.figsize": (15, 10)})

# %%
verbose = True
root = '../data-delta0'
orientations = ['FF', 'FR', 'RF', 'RR']
datasource = "" #set to shuffled for randomized data input

if verbose:
    print("Data for stacked bar plot. Significantly non-random 2x2 tables are starred.")
    
for species in ['Scer', 'Cele', 'Crei', 'Mtru', 'Agam', 'Dmel', 'Xtro', 'Drer', 'Mmus', 'Hsap']:
    if (datasource == 'shuffled'):
      datafile = '{}/{}/{}.iloci.shuffled.tsv'.format(root,species,species)
    else:
      datafile = '{}/{}/{}.iloci.tsv'.format(root,species,species)
    data = pandas.read_csv(datafile,sep='\t')
    data['LogLength'] = numpy.log10(data['Length'])
    
    iiloci = data.loc[data.LocusClass == 'iiLocus']
    
    FRmatrix = numpy.zeros((2,2))
    i = 1
    for o in orientations:
        subset = iiloci.loc[(iiloci.FlankGeneOrient == o)]
        if i == 1:
            FRmatrix[0,0] = len(subset)
        if i == 2:
            FRmatrix[0,1] = len(subset)
        if i == 3:
            FRmatrix[1,0] = len(subset)
        if i == 4:
            FRmatrix[1,1] = len(subset)
        i = i + 1
    
    if verbose:
        print("")
        print("Species: ",species)
        print("Overall FR type counts (total: ",len(iiloci),"):")
        print(FRmatrix.astype(int))
        
    subsets = list()
    FRmatrix = numpy.zeros((2,2))
    llist = []
    bins=numpy.log10(numpy.logspace(2, 5, 21))

    #Note: We use 20 bins on 10 species. Thus, the Fisher Exact Test
    #      significance level is conservatively set to 0.01/20.
    
    for b in range(0,20):
        i = 1
        for orient in orientations:
            subset = iiloci.loc[(iiloci.FlankGeneOrient == orient) &
                                (iiloci.LogLength >= bins[b]) &
                                (iiloci.LogLength <  bins[b+1])]
            if i == 1:
              FRmatrix[0,0] = len(subset)
            if i == 2:
              FRmatrix[0,1] = len(subset)
            if i == 3:
              FRmatrix[1,0] = len(subset)
            if i == 4:
              FRmatrix[1,1] = len(subset)
            i = i + 1
        
        oddsration, pvalue = scipy.stats.fisher_exact(FRmatrix.astype(int))
        height = FRmatrix[0,0] + FRmatrix[0,1] + FRmatrix[1,0] + FRmatrix[1,1]
        if pvalue <= 0.01/20:
            psymbol = "*"
        else:
            psymbol = ""
        if verbose:
            print("")
            print("Length bin: ",int(10**bins[b])," to ",int(10**bins[b+1]+1))
            print("Number of iiLoci in this bin: ",int(height))
            print("FR type matrix (",psymbol,"):")
            print(FRmatrix.astype(int))
        llist.append([(bins[b]+bins[b+1])/2,height,psymbol])
    
    for o in orientations:
        subset = iiloci.loc[(iiloci.FlankGeneOrient == o)]
        subsets.append(subset['LogLength'])
    
    fig, axis = plt.subplots()
    _ = plt.hist(subsets, stacked=True,
                 bins=numpy.log10(numpy.logspace(2, 5, 21)),
                 label=orientations, edgecolor='black', linewidth=0.6)
    if (datasource == 'shuffled'):
      _ = plt.title('Shuffled')
    else:
      _ = plt.title('Observed')
    _ = plt.legend()
    _ = axis.set_xlabel('iiLocus Length (bp)', fontsize=16)
    _ = axis.set_ylabel('Frequency', fontsize=16)
    _ = axis.set_xlim((numpy.log10(100), numpy.log10(100000)))
    _ = axis.set_xticks([numpy.log10(100), 3, 4, 5])
    _ = axis.set_xticklabels(['100','1,000', '10,000', '100,000'])
    _ = plt.suptitle(species, fontsize=20)
        
    for i in range(len(llist)):
        axis.text(llist[i][0], llist[i][1] + 5, llist[i][2],
                  fontsize=20, ha='center', va='bottom')
           
    plotfile = "../figures/LSB20GB-SuppFig3_%s%s.png" % (datasource, species)
    plt.savefig(plotfile)
    _ = plt.show()
# Out:
# Data for stacked bar plot. Significantly non-random 2x2 tables are starred.
#
# Species:  Scer
# Overall FR type counts (total:  6209 ):
# [[1529 1602]
#  [1610 1468]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  286
# FR type matrix (  ):
# [[ 31 220]
#  [ 13  22]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  548
# FR type matrix ( * ):
# [[ 82 300]
#  [ 79  87]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  1114
# FR type matrix (  ):
# [[245 324]
#  [262 283]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  1260
# FR type matrix ( * ):
# [[378 291]
#  [243 348]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  1041
# FR type matrix ( * ):
# [[331 129]
#  [266 315]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  754
# FR type matrix (  ):
# [[195  65]
#  [320 174]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  433
# FR type matrix (  ):
# [[105  48]
#  [190  90]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  244
# FR type matrix (  ):
# [[ 64  20]
#  [100  60]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  140
# FR type matrix (  ):
# [[41  8]
#  [61 30]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  68
# FR type matrix (  ):
# [[10  3]
#  [34 21]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  20
# FR type matrix (  ):
# [[4 2]
#  [8 6]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  11
# FR type matrix (  ):
# [[2 2]
#  [4 3]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  5
# FR type matrix (  ):
# [[1 0]
#  [4 0]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  2
# FR type matrix (  ):
# [[2 0]
#  [0 0]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Cele
# Overall FR type counts (total:  25021 ):
# [[7673 5575]
#  [5575 6198]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  1650
# FR type matrix ( * ):
# [[540 347]
#  [320 443]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  1800
# FR type matrix ( * ):
# [[565 377]
#  [417 441]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  2095
# FR type matrix ( * ):
# [[596 504]
#  [453 542]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  2222
# FR type matrix ( * ):
# [[664 482]
#  [494 582]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  2167
# FR type matrix ( * ):
# [[679 472]
#  [484 532]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  2293
# FR type matrix ( * ):
# [[712 484]
#  [513 584]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  2141
# FR type matrix ( * ):
# [[657 451]
#  [484 549]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  1846
# FR type matrix ( * ):
# [[571 359]
#  [464 452]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  1647
# FR type matrix ( * ):
# [[554 312]
#  [384 397]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1460
# FR type matrix ( * ):
# [[458 292]
#  [345 365]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1115
# FR type matrix (  ):
# [[322 214]
#  [324 255]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  739
# FR type matrix (  ):
# [[228 149]
#  [197 165]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  508
# FR type matrix (  ):
# [[155 101]
#  [149 103]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  265
# FR type matrix (  ):
# [[81 46]
#  [67 71]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  91
# FR type matrix (  ):
# [[20 22]
#  [33 16]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  24
# FR type matrix (  ):
# [[6 6]
#  [5 7]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  5
# FR type matrix (  ):
# [[0 2]
#  [2 1]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  2
# FR type matrix (  ):
# [[0 0]
#  [2 0]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Crei
# Overall FR type counts (total:  13462 ):
# [[2983 3771]
#  [3779 2929]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  402
# FR type matrix ( * ):
# [[ 81  74]
#  [180  67]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  424
# FR type matrix (  ):
# [[ 82  69]
#  [190  83]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  548
# FR type matrix ( * ):
# [[100 101]
#  [232 115]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  826
# FR type matrix ( * ):
# [[149 146]
#  [367 164]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  950
# FR type matrix ( * ):
# [[193 225]
#  [340 192]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  1182
# FR type matrix ( * ):
# [[248 294]
#  [416 224]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  1334
# FR type matrix ( * ):
# [[267 421]
#  [378 268]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  1439
# FR type matrix ( * ):
# [[316 456]
#  [355 312]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  1359
# FR type matrix (  ):
# [[315 497]
#  [242 305]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1115
# FR type matrix (  ):
# [[278 363]
#  [244 230]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  859
# FR type matrix (  ):
# [[203 250]
#  [190 216]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  714
# FR type matrix (  ):
# [[177 199]
#  [152 186]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  688
# FR type matrix (  ):
# [[177 187]
#  [148 176]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  556
# FR type matrix (  ):
# [[153 153]
#  [125 125]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  339
# FR type matrix (  ):
# [[89 92]
#  [74 84]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  236
# FR type matrix (  ):
# [[50 63]
#  [56 67]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  102
# FR type matrix (  ):
# [[20 34]
#  [23 25]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  51
# FR type matrix (  ):
# [[14 11]
#  [10 16]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  20
# FR type matrix (  ):
# [[6 8]
#  [5 1]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  8
# FR type matrix (  ):
# [[1 2]
#  [2 3]]
# Species:  Mtru
# Overall FR type counts (total:  50229 ):
# [[13147 11977]
#  [11957 13148]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  352
# FR type matrix (  ):
# [[ 74 151]
#  [ 57  70]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  449
# FR type matrix ( * ):
# [[ 91 192]
#  [ 91  75]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  692
# FR type matrix ( * ):
# [[130 296]
#  [129 137]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  1036
# FR type matrix ( * ):
# [[207 462]
#  [168 199]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  1573
# FR type matrix ( * ):
# [[286 694]
#  [288 305]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  2203
# FR type matrix ( * ):
# [[486 852]
#  [412 453]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  3266
# FR type matrix (  ):
# [[ 808 1068]
#  [ 638  752]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  4264
# FR type matrix (  ):
# [[1097 1215]
#  [ 845 1107]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  5166
# FR type matrix ( * ):
# [[1463 1239]
#  [1061 1403]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  5639
# FR type matrix ( * ):
# [[1548 1222]
#  [1288 1581]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  5935
# FR type matrix ( * ):
# [[1656 1127]
#  [1420 1732]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  5731
# FR type matrix ( * ):
# [[1663  981]
#  [1513 1574]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  5016
# FR type matrix ( * ):
# [[1399  812]
#  [1414 1391]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  3713
# FR type matrix ( * ):
# [[1004  588]
#  [1134  987]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  2327
# FR type matrix (  ):
# [[571 417]
#  [714 625]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  1184
# FR type matrix (  ):
# [[294 209]
#  [378 303]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  562
# FR type matrix (  ):
# [[143  90]
#  [176 153]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  244
# FR type matrix (  ):
# [[64 49]
#  [59 72]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  119
# FR type matrix (  ):
# [[27 22]
#  [40 30]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  50
# FR type matrix (  ):
# [[10 15]
#  [12 13]]
# Species:  Agam
# Overall FR type counts (total:  11902 ):
# [[2964 3014]
#  [3023 2901]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  160
# FR type matrix ( * ):
# [[18 77]
#  [37 28]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  226
# FR type matrix (  ):
# [[42 75]
#  [38 71]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  338
# FR type matrix (  ):
# [[ 93 121]
#  [ 55  69]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  546
# FR type matrix ( * ):
# [[125 138]
#  [184  99]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  591
# FR type matrix (  ):
# [[155 132]
#  [182 122]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  613
# FR type matrix (  ):
# [[139 147]
#  [194 133]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  686
# FR type matrix (  ):
# [[153 162]
#  [183 188]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  816
# FR type matrix (  ):
# [[198 220]
#  [190 208]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  952
# FR type matrix (  ):
# [[240 241]
#  [221 250]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  926
# FR type matrix (  ):
# [[242 264]
#  [219 201]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  895
# FR type matrix (  ):
# [[216 254]
#  [194 231]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  803
# FR type matrix (  ):
# [[192 211]
#  [199 201]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  727
# FR type matrix (  ):
# [[187 160]
#  [172 208]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  589
# FR type matrix (  ):
# [[167 123]
#  [130 169]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  514
# FR type matrix (  ):
# [[140  87]
#  [138 149]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  483
# FR type matrix (  ):
# [[146  75]
#  [140 122]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  452
# FR type matrix (  ):
# [[136  73]
#  [147  96]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  404
# FR type matrix (  ):
# [[104  70]
#  [122 108]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  327
# FR type matrix (  ):
# [[ 95  54]
#  [104  74]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  258
# FR type matrix (  ):
# [[66 44]
#  [79 69]]
# Species:  Dmel
# Overall FR type counts (total:  12024 ):
# [[3634 2846]
#  [2874 2670]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  706
# FR type matrix (  ):
# [[200 235]
#  [134 137]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  834
# FR type matrix (  ):
# [[277 220]
#  [156 181]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  1157
# FR type matrix ( * ):
# [[346 194]
#  [286 331]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  1177
# FR type matrix (  ):
# [[438 186]
#  [338 215]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  1076
# FR type matrix ( * ):
# [[365 165]
#  [294 252]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  869
# FR type matrix (  ):
# [[302 142]
#  [253 172]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  691
# FR type matrix ( * ):
# [[215 120]
#  [170 186]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  598
# FR type matrix ( * ):
# [[189 111]
#  [133 165]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  534
# FR type matrix (  ):
# [[151 100]
#  [157 126]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  461
# FR type matrix (  ):
# [[127  88]
#  [120 126]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  428
# FR type matrix (  ):
# [[120  81]
#  [112 115]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  423
# FR type matrix (  ):
# [[116  83]
#  [117 107]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  384
# FR type matrix (  ):
# [[130  87]
#  [ 81  86]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  370
# FR type matrix (  ):
# [[107  92]
#  [ 97  74]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  268
# FR type matrix (  ):
# [[69 63]
#  [59 77]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  219
# FR type matrix (  ):
# [[65 48]
#  [52 54]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  124
# FR type matrix (  ):
# [[40 27]
#  [33 24]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  72
# FR type matrix (  ):
# [[16 20]
#  [17 19]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  28
# FR type matrix (  ):
# [[ 9 13]
#  [ 6  0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  17
# FR type matrix (  ):
# [[5 4]
#  [4 4]]
# Species:  Xtro
# Overall FR type counts (total:  23175 ):
# [[6427 5248]
#  [5192 6308]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  347
# FR type matrix (  ):
# [[ 55  20]
#  [240  32]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  251
# FR type matrix ( * ):
# [[ 39  27]
#  [162  23]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  404
# FR type matrix (  ):
# [[185  29]
#  [140  50]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  542
# FR type matrix ( * ):
# [[186  71]
#  [114 171]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  636
# FR type matrix ( * ):
# [[206  99]
#  [165 166]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  668
# FR type matrix ( * ):
# [[206 185]
#  [ 86 191]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  629
# FR type matrix (  ):
# [[171 214]
#  [ 77 167]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  550
# FR type matrix (  ):
# [[120 230]
#  [ 54 146]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  788
# FR type matrix (  ):
# [[188 294]
#  [105 201]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1149
# FR type matrix ( * ):
# [[305 345]
#  [163 336]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1483
# FR type matrix ( * ):
# [[403 452]
#  [209 419]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1733
# FR type matrix ( * ):
# [[526 441]
#  [260 506]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1958
# FR type matrix ( * ):
# [[561 471]
#  [343 583]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1936
# FR type matrix ( * ):
# [[565 401]
#  [383 587]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1921
# FR type matrix ( * ):
# [[517 385]
#  [416 603]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  1688
# FR type matrix ( * ):
# [[499 329]
#  [397 463]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  1521
# FR type matrix ( * ):
# [[439 293]
#  [370 419]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  1192
# FR type matrix (  ):
# [[343 237]
#  [301 311]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  876
# FR type matrix (  ):
# [[226 172]
#  [252 226]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  682
# FR type matrix (  ):
# [[181 147]
#  [188 166]]
# Species:  Drer
# Overall FR type counts (total:  34111 ):
# [[10365  6782]
#  [ 6789 10175]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  854
# FR type matrix ( * ):
# [[362  52]
#  [ 79 361]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  603
# FR type matrix ( * ):
# [[233  41]
#  [ 78 251]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  857
# FR type matrix ( * ):
# [[429  90]
#  [191 147]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  698
# FR type matrix (  ):
# [[169  90]
#  [252 187]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  1009
# FR type matrix ( * ):
# [[363  77]
#  [151 418]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  1451
# FR type matrix ( * ):
# [[531 226]
#  [217 477]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  1586
# FR type matrix ( * ):
# [[544 284]
#  [292 466]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  1908
# FR type matrix ( * ):
# [[680 306]
#  [374 548]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  2229
# FR type matrix ( * ):
# [[633 430]
#  [466 700]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  2646
# FR type matrix ( * ):
# [[723 584]
#  [536 803]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  2735
# FR type matrix ( * ):
# [[781 606]
#  [523 825]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  2881
# FR type matrix ( * ):
# [[821 653]
#  [556 851]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  2648
# FR type matrix ( * ):
# [[726 617]
#  [512 793]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  2385
# FR type matrix ( * ):
# [[681 534]
#  [470 700]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1956
# FR type matrix ( * ):
# [[552 456]
#  [357 591]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  1582
# FR type matrix ( * ):
# [[427 357]
#  [324 474]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  1196
# FR type matrix (  ):
# [[314 291]
#  [272 319]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  1020
# FR type matrix (  ):
# [[264 232]
#  [243 281]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  805
# FR type matrix (  ):
# [[221 171]
#  [201 212]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  568
# FR type matrix (  ):
# [[150 115]
#  [140 163]]
# Species:  Mmus
# Overall FR type counts (total:  28306 ):
# [[7321 6729]
#  [6726 7530]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  423
# FR type matrix ( * ):
# [[ 66  61]
#  [261  35]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  357
# FR type matrix ( * ):
# [[ 51  57]
#  [218  31]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  349
# FR type matrix ( * ):
# [[ 71  50]
#  [179  49]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  371
# FR type matrix (  ):
# [[ 85  85]
#  [136  65]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  428
# FR type matrix (  ):
# [[ 98 139]
#  [111  80]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  406
# FR type matrix (  ):
# [[100 133]
#  [ 79  94]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  508
# FR type matrix (  ):
# [[133 187]
#  [ 88 100]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  647
# FR type matrix (  ):
# [[166 199]
#  [100 182]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  875
# FR type matrix (  ):
# [[230 318]
#  [112 215]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1075
# FR type matrix ( * ):
# [[289 326]
#  [163 297]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1265
# FR type matrix (  ):
# [[344 371]
#  [217 333]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1559
# FR type matrix ( * ):
# [[435 396]
#  [254 474]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1916
# FR type matrix ( * ):
# [[527 470]
#  [387 532]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  2098
# FR type matrix ( * ):
# [[586 467]
#  [409 636]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  2300
# FR type matrix ( * ):
# [[612 531]
#  [493 664]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  2344
# FR type matrix ( * ):
# [[652 471]
#  [509 712]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  2274
# FR type matrix ( * ):
# [[590 497]
#  [494 693]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  1974
# FR type matrix ( * ):
# [[533 426]
#  [453 562]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  1562
# FR type matrix ( * ):
# [[424 315]
#  [360 463]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  1307
# FR type matrix ( * ):
# [[345 268]
#  [299 395]]
# Species:  Hsap
# Overall FR type counts (total:  26840 ):
# [[7232 6453]
#  [6468 6687]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  386
# FR type matrix ( * ):
# [[ 61  45]
#  [251  29]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  375
# FR type matrix ( * ):
# [[ 76  59]
#  [197  43]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  372
# FR type matrix ( * ):
# [[ 72  69]
#  [188  43]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  361
# FR type matrix ( * ):
# [[ 72  76]
#  [151  62]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  385
# FR type matrix (  ):
# [[ 94  87]
#  [117  87]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  439
# FR type matrix (  ):
# [[112 135]
#  [ 93  99]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  542
# FR type matrix (  ):
# [[164 144]
#  [105 129]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  640
# FR type matrix (  ):
# [[173 183]
#  [105 179]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  844
# FR type matrix ( * ):
# [[280 228]
#  [140 196]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  985
# FR type matrix ( * ):
# [[270 283]
#  [162 270]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1110
# FR type matrix ( * ):
# [[296 351]
#  [162 301]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1395
# FR type matrix ( * ):
# [[424 346]
#  [230 395]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1522
# FR type matrix ( * ):
# [[432 400]
#  [271 419]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1800
# FR type matrix ( * ):
# [[522 429]
#  [319 530]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1953
# FR type matrix ( * ):
# [[575 463]
#  [385 530]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  2048
# FR type matrix ( * ):
# [[573 463]
#  [423 589]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  2053
# FR type matrix ( * ):
# [[583 495]
#  [446 529]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  1918
# FR type matrix (  ):
# [[528 465]
#  [434 491]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  1701
# FR type matrix (  ):
# [[455 376]
#  [417 453]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  1412
# FR type matrix (  ):
# [[379 328]
#  [326 379]]
