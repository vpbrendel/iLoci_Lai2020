# %%
from __future__ import division
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt
import numpy
import scipy
import seaborn
seaborn.set_context({"figure.figsize": (15, 10)})

# %%
verbose = True
root = '../data-delta0'
orientations = ['FF', 'FR', 'RF', 'RR']
datasource = "shuffled" #set to shuffled for randomized data input

if verbose:
    print("Data for stacked bar plot. Significantly non-random 2x2 tables are starred.")
    
for species in ['Scer', 'Cele', 'Crei', 'Mtru', 'Agam', 'Dmel', 'Xtro', 'Drer', 'Mmus', 'Hsap']:
    if (datasource == 'shuffled'):
      datafile = '{}/{}/{}.iloci.shuffled.tsv'.format(root,species,species)
    else:
      datafile = '{}/{}/{}.iloci.tsv'.format(root,species,species)
    data = pandas.read_csv(datafile,sep='\t')
    data['LogLength'] = numpy.log10(data['Length'])
    
    iiloci = data.loc[data.LocusClass == 'iiLocus']
    
    FRmatrix = numpy.zeros((2,2))
    i = 1
    for o in orientations:
        subset = iiloci.loc[(iiloci.FlankGeneOrient == o)]
        if i == 1:
            FRmatrix[0,0] = len(subset)
        if i == 2:
            FRmatrix[0,1] = len(subset)
        if i == 3:
            FRmatrix[1,0] = len(subset)
        if i == 4:
            FRmatrix[1,1] = len(subset)
        i = i + 1
    
    if verbose:
        print("")
        print("Species: ",species)
        print("Overall FR type counts (total: ",len(iiloci),"):")
        print(FRmatrix.astype(int))
        
    subsets = list()
    FRmatrix = numpy.zeros((2,2))
    llist = []
    bins=numpy.log10(numpy.logspace(2, 5, 21))

    #Note: We use 20 bins on 10 species. Thus, the Fisher Exact Test
    #      significance level is conservatively set to 0.01/20.
    
    for b in range(0,20):
        i = 1
        for orient in orientations:
            subset = iiloci.loc[(iiloci.FlankGeneOrient == orient) &
                                (iiloci.LogLength >= bins[b]) &
                                (iiloci.LogLength <  bins[b+1])]
            if i == 1:
              FRmatrix[0,0] = len(subset)
            if i == 2:
              FRmatrix[0,1] = len(subset)
            if i == 3:
              FRmatrix[1,0] = len(subset)
            if i == 4:
              FRmatrix[1,1] = len(subset)
            i = i + 1
        
        oddsration, pvalue = scipy.stats.fisher_exact(FRmatrix.astype(int))
        height = FRmatrix[0,0] + FRmatrix[0,1] + FRmatrix[1,0] + FRmatrix[1,1]
        if pvalue <= 0.01/20:
            psymbol = "*"
        else:
            psymbol = ""
        if verbose:
            print("")
            print("Length bin: ",int(10**bins[b])," to ",int(10**bins[b+1]+1))
            print("Number of iiLoci in this bin: ",int(height))
            print("FR type matrix (",psymbol,"):")
            print(FRmatrix.astype(int))
        llist.append([(bins[b]+bins[b+1])/2,height,psymbol])
    
    for o in orientations:
        subset = iiloci.loc[(iiloci.FlankGeneOrient == o)]
        subsets.append(subset['LogLength'])
    
    fig, axis = plt.subplots()
    _ = plt.hist(subsets, stacked=True,
                 bins=numpy.log10(numpy.logspace(2, 5, 21)),
                 label=orientations, edgecolor='black', linewidth=0.6)
    if (datasource == 'shuffled'):
      _ = plt.title('Shuffled')
    else:
      _ = plt.title('Observed')
    _ = plt.legend()
    _ = axis.set_xlabel('iiLocus Length (bp)', fontsize=16)
    _ = axis.set_ylabel('Frequency', fontsize=16)
    _ = axis.set_xlim((numpy.log10(100), numpy.log10(100000)))
    _ = axis.set_xticks([numpy.log10(100), 3, 4, 5])
    _ = axis.set_xticklabels(['100','1,000', '10,000', '100,000'])
    _ = plt.suptitle(species, fontsize=20)
        
    for i in range(len(llist)):
        axis.text(llist[i][0], llist[i][1] + 5, llist[i][2],
                  fontsize=20, ha='center', va='bottom')
           
    plotfile = "../figures/LSB20GB-SuppFig4_%s%s.png" % (datasource, species)
    plt.savefig(plotfile)
    _ = plt.show()
# Out:
# Data for stacked bar plot. Significantly non-random 2x2 tables are starred.
#
# Species:  Scer
# Overall FR type counts (total:  133 ):
# [[32 34]
#  [42 25]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  18
# FR type matrix (  ):
# [[5 7]
#  [5 1]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  46
# FR type matrix (  ):
# [[10 10]
#  [13 13]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  31
# FR type matrix (  ):
# [[ 9  8]
#  [11  3]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  27
# FR type matrix (  ):
# [[6 7]
#  [6 8]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  7
# FR type matrix (  ):
# [[0 2]
#  [5 0]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  3
# FR type matrix (  ):
# [[2 0]
#  [1 0]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1
# FR type matrix (  ):
# [[0 0]
#  [1 0]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Cele
# Overall FR type counts (total:  7390 ):
# [[2208 1762]
#  [1805 1615]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  295
# FR type matrix (  ):
# [[87 73]
#  [68 67]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  1062
# FR type matrix (  ):
# [[306 266]
#  [261 229]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  1200
# FR type matrix (  ):
# [[337 284]
#  [304 275]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  1278
# FR type matrix (  ):
# [[356 311]
#  [321 290]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  1197
# FR type matrix (  ):
# [[375 269]
#  [295 258]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1001
# FR type matrix (  ):
# [[316 236]
#  [238 211]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  746
# FR type matrix (  ):
# [[246 183]
#  [168 149]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  396
# FR type matrix (  ):
# [[119  88]
#  [102  87]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  174
# FR type matrix (  ):
# [[55 41]
#  [40 38]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  36
# FR type matrix (  ):
# [[11 10]
#  [ 7  8]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  5
# FR type matrix (  ):
# [[0 1]
#  [1 3]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Crei
# Overall FR type counts (total:  6398 ):
# [[1634 1560]
#  [1653 1551]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  117
# FR type matrix (  ):
# [[30 34]
#  [28 25]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  470
# FR type matrix (  ):
# [[114 119]
#  [121 116]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  592
# FR type matrix (  ):
# [[146 142]
#  [153 151]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  699
# FR type matrix (  ):
# [[186 175]
#  [177 161]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  850
# FR type matrix (  ):
# [[228 199]
#  [225 198]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  927
# FR type matrix (  ):
# [[229 210]
#  [252 236]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  861
# FR type matrix (  ):
# [[236 194]
#  [213 218]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  811
# FR type matrix (  ):
# [[190 223]
#  [206 192]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  587
# FR type matrix (  ):
# [[150 142]
#  [154 141]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  308
# FR type matrix (  ):
# [[86 71]
#  [84 67]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  131
# FR type matrix (  ):
# [[28 41]
#  [30 32]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  30
# FR type matrix (  ):
# [[7 8]
#  [6 9]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  13
# FR type matrix (  ):
# [[4 1]
#  [4 4]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  2
# FR type matrix (  ):
# [[0 1]
#  [0 1]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Mtru
# Overall FR type counts (total:  36494 ):
# [[9106 9067]
#  [9155 9166]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  459
# FR type matrix (  ):
# [[110 112]
#  [120 117]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  1531
# FR type matrix (  ):
# [[405 379]
#  [353 394]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  2121
# FR type matrix (  ):
# [[561 550]
#  [528 482]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  2729
# FR type matrix (  ):
# [[674 677]
#  [696 682]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  3505
# FR type matrix (  ):
# [[831 876]
#  [896 902]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  4144
# FR type matrix (  ):
# [[ 991 1024]
#  [1043 1086]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  4865
# FR type matrix (  ):
# [[1181 1220]
#  [1234 1230]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  5047
# FR type matrix (  ):
# [[1266 1249]
#  [1287 1245]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  4687
# FR type matrix (  ):
# [[1187 1190]
#  [1139 1171]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  3720
# FR type matrix (  ):
# [[971 905]
#  [930 914]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  2253
# FR type matrix (  ):
# [[590 541]
#  [563 559]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  1068
# FR type matrix (  ):
# [[262 257]
#  [270 279]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  305
# FR type matrix (  ):
# [[62 74]
#  [83 86]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  58
# FR type matrix (  ):
# [[14 13]
#  [13 18]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  2
# FR type matrix (  ):
# [[1 0]
#  [0 1]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
# Species:  Agam
# Overall FR type counts (total:  10517 ):
# [[2665 2643]
#  [2629 2580]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  53
# FR type matrix (  ):
# [[14 13]
#  [12 14]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  169
# FR type matrix (  ):
# [[44 47]
#  [37 41]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  230
# FR type matrix (  ):
# [[67 54]
#  [60 49]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  363
# FR type matrix (  ):
# [[81 92]
#  [93 97]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  489
# FR type matrix (  ):
# [[121 124]
#  [118 126]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  637
# FR type matrix (  ):
# [[169 161]
#  [148 159]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  917
# FR type matrix (  ):
# [[236 232]
#  [221 228]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1034
# FR type matrix (  ):
# [[253 264]
#  [264 253]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1193
# FR type matrix (  ):
# [[301 308]
#  [295 289]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1260
# FR type matrix (  ):
# [[319 311]
#  [339 291]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1328
# FR type matrix (  ):
# [[322 340]
#  [311 355]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  1149
# FR type matrix (  ):
# [[291 282]
#  [301 275]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  883
# FR type matrix (  ):
# [[247 201]
#  [237 198]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  518
# FR type matrix (  ):
# [[126 147]
#  [120 125]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  217
# FR type matrix (  ):
# [[56 45]
#  [53 63]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  64
# FR type matrix (  ):
# [[15 18]
#  [18 13]]
# Species:  Dmel
# Overall FR type counts (total:  7743 ):
# [[2228 1961]
#  [1926 1628]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  140
# FR type matrix (  ):
# [[56 31]
#  [29 24]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  510
# FR type matrix (  ):
# [[137 135]
#  [119 119]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  624
# FR type matrix (  ):
# [[188 155]
#  [154 127]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  843
# FR type matrix (  ):
# [[254 222]
#  [192 175]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  974
# FR type matrix (  ):
# [[305 215]
#  [261 193]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1063
# FR type matrix (  ):
# [[308 260]
#  [269 226]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  1096
# FR type matrix (  ):
# [[300 279]
#  [260 257]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1012
# FR type matrix (  ):
# [[269 258]
#  [275 210]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  762
# FR type matrix (  ):
# [[215 204]
#  [196 147]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  449
# FR type matrix (  ):
# [[132 126]
#  [104  87]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  174
# FR type matrix (  ):
# [[35 51]
#  [44 44]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  58
# FR type matrix (  ):
# [[15 14]
#  [16 13]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  12
# FR type matrix (  ):
# [[4 4]
#  [1 3]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  9
# FR type matrix (  ):
# [[6 2]
#  [1 0]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  5
# FR type matrix (  ):
# [[2 0]
#  [1 2]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  4
# FR type matrix (  ):
# [[1 2]
#  [0 1]]
# Species:  Xtro
# Overall FR type counts (total:  19548 ):
# [[4998 4817]
#  [4805 4928]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  49
# FR type matrix (  ):
# [[12 11]
#  [16 10]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  144
# FR type matrix (  ):
# [[42 36]
#  [38 28]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  239
# FR type matrix (  ):
# [[68 65]
#  [61 45]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  328
# FR type matrix (  ):
# [[101  72]
#  [ 80  75]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  416
# FR type matrix (  ):
# [[109  95]
#  [105 107]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  610
# FR type matrix (  ):
# [[167 162]
#  [129 152]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  749
# FR type matrix (  ):
# [[181 192]
#  [189 187]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  1061
# FR type matrix (  ):
# [[284 257]
#  [243 277]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1314
# FR type matrix (  ):
# [[304 348]
#  [322 340]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1724
# FR type matrix (  ):
# [[440 419]
#  [433 432]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1955
# FR type matrix (  ):
# [[523 453]
#  [489 490]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  2207
# FR type matrix (  ):
# [[570 525]
#  [547 565]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  2496
# FR type matrix (  ):
# [[661 620]
#  [582 633]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  2242
# FR type matrix (  ):
# [[554 564]
#  [547 577]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  1846
# FR type matrix (  ):
# [[442 473]
#  [460 471]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  1222
# FR type matrix (  ):
# [[299 295]
#  [319 309]]
# Species:  Drer
# Overall FR type counts (total:  29435 ):
# [[7507 7349]
#  [7296 7283]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  151
# FR type matrix (  ):
# [[40 45]
#  [32 34]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  537
# FR type matrix (  ):
# [[135 131]
#  [143 128]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  692
# FR type matrix (  ):
# [[189 172]
#  [156 175]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  913
# FR type matrix (  ):
# [[213 231]
#  [250 219]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  1311
# FR type matrix (  ):
# [[316 302]
#  [357 336]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  1703
# FR type matrix (  ):
# [[468 425]
#  [397 413]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  2136
# FR type matrix (  ):
# [[534 539]
#  [557 506]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  2556
# FR type matrix (  ):
# [[650 641]
#  [620 645]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  3097
# FR type matrix (  ):
# [[786 796]
#  [754 761]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  3378
# FR type matrix (  ):
# [[864 825]
#  [865 824]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  3616
# FR type matrix (  ):
# [[909 917]
#  [863 927]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  3309
# FR type matrix (  ):
# [[863 797]
#  [808 841]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  2667
# FR type matrix (  ):
# [[693 691]
#  [626 657]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  1916
# FR type matrix (  ):
# [[505 472]
#  [482 457]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  973
# FR type matrix (  ):
# [[213 259]
#  [251 250]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  358
# FR type matrix (  ):
# [[97 85]
#  [97 79]]
# Species:  Mmus
# Overall FR type counts (total:  27411 ):
# [[6738 6861]
#  [6873 6939]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  44
# FR type matrix (  ):
# [[ 4 13]
#  [13 14]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  132
# FR type matrix (  ):
# [[28 35]
#  [29 40]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  190
# FR type matrix (  ):
# [[52 43]
#  [49 46]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  280
# FR type matrix (  ):
# [[77 78]
#  [67 58]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  344
# FR type matrix (  ):
# [[88 86]
#  [83 87]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  484
# FR type matrix (  ):
# [[122 117]
#  [123 122]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  727
# FR type matrix (  ):
# [[175 178]
#  [179 195]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  909
# FR type matrix (  ):
# [[247 215]
#  [205 242]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1261
# FR type matrix (  ):
# [[316 315]
#  [334 296]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1692
# FR type matrix (  ):
# [[425 384]
#  [459 424]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  2142
# FR type matrix (  ):
# [[541 561]
#  [501 539]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  2595
# FR type matrix (  ):
# [[633 630]
#  [668 664]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  3073
# FR type matrix (  ):
# [[723 801]
#  [792 757]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  3298
# FR type matrix (  ):
# [[830 820]
#  [776 872]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  3300
# FR type matrix (  ):
# [[809 846]
#  [782 863]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  2831
# FR type matrix (  ):
# [[675 718]
#  [718 720]]
# Species:  Hsap
# Overall FR type counts (total:  26006 ):
# [[6755 6528]
#  [6515 6208]]
#
# Length bin:  100  to  142
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  141  to  200
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  199  to  282
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  281  to  399
# Number of iiLoci in this bin:  0
# FR type matrix (  ):
# [[0 0]
#  [0 0]]
#
# Length bin:  398  to  563
# Number of iiLoci in this bin:  36
# FR type matrix (  ):
# [[ 6 13]
#  [ 7 10]]
#
# Length bin:  562  to  795
# Number of iiLoci in this bin:  108
# FR type matrix (  ):
# [[26 29]
#  [24 29]]
#
# Length bin:  794  to  1123
# Number of iiLoci in this bin:  192
# FR type matrix (  ):
# [[50 37]
#  [50 55]]
#
# Length bin:  1122  to  1585
# Number of iiLoci in this bin:  270
# FR type matrix (  ):
# [[65 64]
#  [76 65]]
#
# Length bin:  1584  to  2239
# Number of iiLoci in this bin:  337
# FR type matrix (  ):
# [[80 80]
#  [83 94]]
#
# Length bin:  2238  to  3163
# Number of iiLoci in this bin:  489
# FR type matrix (  ):
# [[131 117]
#  [118 123]]
#
# Length bin:  3162  to  4467
# Number of iiLoci in this bin:  696
# FR type matrix (  ):
# [[183 168]
#  [177 168]]
#
# Length bin:  4466  to  6310
# Number of iiLoci in this bin:  881
# FR type matrix (  ):
# [[207 216]
#  [241 217]]
#
# Length bin:  6309  to  8913
# Number of iiLoci in this bin:  1123
# FR type matrix (  ):
# [[313 289]
#  [267 254]]
#
# Length bin:  8912  to  12590
# Number of iiLoci in this bin:  1588
# FR type matrix (  ):
# [[412 401]
#  [395 380]]
#
# Length bin:  12589  to  17783
# Number of iiLoci in this bin:  1938
# FR type matrix (  ):
# [[528 476]
#  [458 476]]
#
# Length bin:  17782  to  25119
# Number of iiLoci in this bin:  2400
# FR type matrix (  ):
# [[635 600]
#  [581 584]]
#
# Length bin:  25118  to  35482
# Number of iiLoci in this bin:  2745
# FR type matrix (  ):
# [[722 666]
#  [697 660]]
#
# Length bin:  35481  to  50119
# Number of iiLoci in this bin:  2967
# FR type matrix (  ):
# [[755 747]
#  [753 712]]
#
# Length bin:  50118  to  70795
# Number of iiLoci in this bin:  3040
# FR type matrix (  ):
# [[800 746]
#  [744 750]]
#
# Length bin:  70794  to  100001
# Number of iiLoci in this bin:  2804
# FR type matrix (  ):
# [[753 722]
#  [714 615]]
